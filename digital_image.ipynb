# %%
# %matplotlib inline
# %cd images
# Out:
# /Users/keriabermudez/Dropbox/Imaging_Class/images
# /Users/keriabermudez/anaconda/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
from skimage import io

# %%
 img = io.imread("SW_Grey.tif")

# %%
io.imshow(img)

# %%
img.shape
# Out:
# (1329, 2256)

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
cropped = img[531:800,1160:1510]

# %%
io.imshow(cropped)

# %% [markdown]
# Lets change some values. But first lets create a copy of the image.

# %%
img_copy = img.copy()

# %%
img_copy[531:800,1160:1510] = 0

# %%
io.imshow(img_copy)

# %%
io.imsave("cropped.tif",cropped)

# %% [markdown]
# # Color Images

# %%
sample_1 = io.imread("Sample_1.tif")

# %%
io.imshow(sample_1)

# %%
sample_1.shape
# Out:
# (1127, 677, 3)

# %%
red = sample_1[:,:,0]

# %%
io.imshow(red)

# %%
io.imsave("Sampple_1_red_grey.tif",red)

# %%
test_img = io.imread("SW.tif")

# %%
io.imshow(test_img)

# %%
test_img.shape
# Out:
# (1329, 2256, 3)

# %%
import skimage.external.tifffile as tf

# %%
with tf.TiffFile('SW_Grey.tif') as tif:
    images = tif.asarray()
    for page in tif:
        for tag in page.tags.values():
            t = tag.name, tag.value
            print(t)
# Out:
# ('strip_offsets', (405,))
# ('bits_per_sample', 8)
# ('strip_byte_counts', (2998224,))
# ('imagej_metadata', 'IJIJinfo\x00\x00\x00\x01\x00S\x00o\x00f\x00t\x00w\x00a\x00r\x00e\x00:\x00 \x00A\x00d\x00o\x00b\x00e\x00 \x00P\x00h\x00o\x00t\x00o\x00s\x00h\x00o\x00p\x00 \x00C\x00C\x00 \x002\x000\x001\x004\x00 \x00(\x00W\x00i\x00n\x00d\x00o\x00w\x00s\x00)\x00\n\x00D\x00a\x00t\x00e\x00T\x00i\x00m\x00e\x00:\x00 \x002\x000\x001\x004\x00:\x000\x008\x00:\x001\x008\x00 \x001\x001\x00:\x004\x002\x00:\x004\x001\x00\n')
# ('orientation', 1)
# ('compression', 1)
# ('image_description', 'ImageJ=1.49q\nunit=\\u00B5m\n')
# ('fill_order', 1)
# ('image_width', 2256)
# ('new_subfile_type', 0)
# ('x_resolution', (2700000, 1000000))
# ('ycbcr_subsampling', 1)
# ('photometric', 1)
# ('resolution_unit', 1)
# ('imagej_byte_counts', (12, 148))
# ('y_resolution', (2700000, 1000000))
# ('ycbcr_positioning', 1)
# ('image_length', 1329)
# ('planar_configuration', 1)
# ('sample_format', 1)
# ('rows_per_strip', 1329)
# ...

# %%
lsm_image = tf.TiffFile("150707_WTstack.lsm")
lsm = lsm_image.asarray()

# %%
lsm.shape
# Out:
# (1, 18, 3, 620, 620)
